# %% [markdown]
# Relationships between variables
# ====================
#
# Copyright 2015 Allen Downey
#
# License: [Creative Commons Attribution 4.0 International](http://creativecommons.org/licenses/by/4.0/)

# %%
# this future import makes this code mostly compatible with Python 2 and 3
from __future__ import print_function, division

import numpy as np
import pandas as pd
import math

import thinkplot
import thinkstats2

np.random.seed(17)

# %matplotlib inline

# %%
def ReadBrfss(filename='CDBRFS08.ASC.gz', compression='gzip', nrows=None):
    """Reads the BRFSS data.

    filename: string
    compression: string
    nrows: int number of rows to read, or None for all

    returns: DataFrame
    """
    var_info = [
        ('age', 101, 102, int),
        ('sex', 143, 143, int),
        ('wtyrago', 127, 130, int),
        ('finalwt', 799, 808, int),
        ('wtkg2', 1254, 1258, int),
        ('htm3', 1251, 1253, int),
        ]
    columns = ['name', 'start', 'end', 'type']
    variables = pd.DataFrame(var_info, columns=columns)
    variables.end += 1
    dct = thinkstats2.FixedWidthVariables(variables, index_base=1)

    df = dct.ReadFixedWidth(filename, compression=compression, nrows=nrows)
    CleanBrfssFrame(df)
    return df

# %%
def CleanBrfssFrame(df):
    """Recodes BRFSS variables.

    df: DataFrame
    """
    # clean age
    df.age.replace([7, 9], float('NaN'), inplace=True)

    # clean height
    df.htm3.replace([999], float('NaN'), inplace=True)

    # clean weight
    df.wtkg2.replace([99999], float('NaN'), inplace=True)
    df.wtkg2 /= 100.0

    # clean weight a year ago
    df.wtyrago.replace([7777, 9999], float('NaN'), inplace=True)
    df['wtyrago'] = df.wtyrago.apply(lambda x: x/2.2 if x < 9000 else x-9000)

# %%
brfss = ReadBrfss(nrows=None)
brfss.shape
# Out:
# (414509, 6)

# %%
complete = brfss.dropna(subset=['htm3', 'wtkg2'])
complete.shape
# Out:
# (395832, 6)

# %%
complete.head()
# Out:
#    age  sex     wtyrago      finalwt   wtkg2  htm3
# 0   82    2   76.363636   185.870345   70.91   157
# 1   65    2   72.727273   126.603027   72.73   163
# 3   61    1   73.636364   517.926275   73.64   170
# 4   26    1   88.636364  1252.624630   88.64   185
# 5   42    1  118.181818   415.161314  109.09   183

# %%
complete.describe()
# Out:
#                  age            sex        wtyrago        finalwt  \
# count  393518.000000  395832.000000  388137.000000  395832.000000
# mean       54.891207       1.612730      79.766921     562.527274
# std        16.742237       0.487127      20.574880    1076.206594
# min        18.000000       1.000000      22.727273       1.695143
# 25%        43.000000       1.000000      64.545455      97.241254
# 50%        55.000000       2.000000      77.272727     234.914579
# 75%        67.000000       2.000000      90.909091     593.585278
# max        99.000000       2.000000     342.272727   60995.111700
#
#                wtkg2           htm3
# count  395832.000000  395832.000000
# mean       79.044413     168.956188
# std        19.547890      10.390752
# min        20.000000      61.000000
# 25%        64.550000     163.000000
# 50%        77.270000     168.000000
# 75%        90.910000     178.000000
# max       300.000000     236.000000

# %%
sample = thinkstats2.SampleRows(complete, 1000)

# %%
heights = sample.htm3
weights = sample.wtkg2

# %%
thinkplot.Scatter(heights, weights)
thinkplot.Config(xlabel='height (cm)',
                 ylabel='weight (kg)',
                 legend=False)

# %%
thinkplot.Scatter(heights, weights)
thinkplot.Config(xlabel='height (cm)',
                 ylabel='weight (kg)',
                 axis=[140, 210, 20, 200],
                 legend=False)

# %%
heights = thinkstats2.Jitter(heights, 2.0)
weights = thinkstats2.Jitter(weights, 0.5)

# %%
thinkplot.Scatter(heights, weights)
thinkplot.Config(xlabel='height (cm)',
                 ylabel='weight (kg)',
                 axis=[140, 210, 20, 200],
                 legend=False)

# %%
sample = thinkstats2.SampleRows(complete, 10000)
heights = sample.htm3
weights = sample.wtkg2
heights = thinkstats2.Jitter(heights, 2.0)
weights = thinkstats2.Jitter(weights, 0.5)

# %%
thinkplot.Scatter(heights, weights)
thinkplot.Config(xlabel='height (cm)',
                 ylabel='weight (kg)',
                 axis=[140, 210, 20, 200],
                 legend=False)

# %%
thinkplot.Scatter(heights, weights, alpha=0.1, s=5)
thinkplot.Config(xlabel='height (cm)',
                 ylabel='weight (kg)',
                 axis=[140, 210, 20, 200],
                 legend=False)

# %%
sample = thinkstats2.SampleRows(complete, 100000)
heights = sample.htm3
weights = sample.wtkg2
heights = thinkstats2.Jitter(heights, 3.5)
weights = thinkstats2.Jitter(weights, 1.5)

# %%
thinkplot.Scatter(heights, weights, alpha=0.1, s=1)
thinkplot.Config(xlabel='height (cm)',
                 ylabel='weight (kg)',
                 axis=[140, 210, 20, 200],
                 legend=False)

# %%
sample = complete
heights = sample.htm3
weights = sample.wtkg2
heights = thinkstats2.Jitter(heights, 3.5)
weights = thinkstats2.Jitter(weights, 1.5)

# %%
thinkplot.Scatter(heights, weights, alpha=0.1, s=0.5)
thinkplot.Config(xlabel='height (cm)',
                 ylabel='weight (kg)',
                 axis=[140, 210, 20, 200],
                 legend=False)

# %%
thinkplot.HexBin(heights, weights)
thinkplot.Config(xlabel='height (cm)',
                 ylabel='weight (kg)',
                 axis=[140, 210, 20, 200],
                 legend=False)

# %%
bins = np.arange(135, 210, 10)
indices = np.digitize(complete.htm3, bins)
groups = complete.groupby(indices)

# %%
mean_heights = [group.htm3.mean() for i, group in groups][1:-1]
cdfs = [thinkstats2.Cdf(group.wtkg2) for i, group in groups][1:-1]

# %%
thinkplot.PrePlot(7)
for mean, cdf in zip(mean_heights, cdfs):
    thinkplot.Cdf(cdf, label='%.0f cm' % mean)
    
thinkplot.Config(xlabel='weight (kg)',
                 ylabel='CDF',
                 axis=[20, 200, 0, 1],
                 legend=True)

# %%
thinkplot.PrePlot(5)
for percent in [90, 75, 50, 25, 10]:
    weight_percentiles = [cdf.Percentile(percent) for cdf in cdfs]
    label = '%dth' % percent
    thinkplot.Plot(mean_heights, weight_percentiles, label=label)
    
thinkplot.Config(xlabel='height (cm)',
                 ylabel='weight (kg)',
                 axis=[135, 220, 35, 145],
                 legend=True)

# %%
thinkplot.PrePlot(5)
for percent in [90, 75, 50, 25, 10]:
    weight_percentiles = [cdf.Percentile(percent) for cdf in cdfs]
    label = '%dth' % percent
    thinkplot.Plot(mean_heights, weight_percentiles, label=label)
    
thinkplot.Config(xlabel='height (cm)',
                 ylabel='weight (kg)',
                 yscale='log',
                 axis=[135, 220, 35, 145],
                 legend=True)

# %%
complete.htm3.corr(complete.wtkg2)
# Out:
# 0.50873647897345775

# %%
complete.htm3.corr(np.log(complete.wtkg2))
# Out:
# 0.53172826059834166

# %%
complete.htm3.corr(complete.wtkg2, method='spearman')
# Out:
# 0.54058462623204784

# %%
inter, slope = thinkstats2.LeastSquares(heights, weights)
inter, slope
# Out:
# (-76.659833255473657, 0.92161084762328827)

# %%
fit_xs, fit_ys = thinkstats2.FitLine(heights, inter, slope)
thinkplot.Scatter(heights, weights, alpha=0.05, s=0.5)
thinkplot.Plot(fit_xs, fit_ys, color='gray')
thinkplot.Config(xlabel='height (cm)',
                 ylabel='weight (kg)',
                 axis=[140, 210, 20, 200],
                 legend=False)

# %%
log_weights = np.log(weights)
inter, slope = thinkstats2.LeastSquares(heights, log_weights)
fit_xs, fit_ys = thinkstats2.FitLine(heights, inter, slope)
thinkplot.Scatter(heights, log_weights, alpha=0.05, s=0.5)
thinkplot.Plot(fit_xs, fit_ys, color='gray')
thinkplot.Config(xlabel='height (cm)',
                 ylabel='log weight (kg)',
                 axis=[140, 210, 3.5, 5.5],
                 legend=False)

# %%
inter, slope = thinkstats2.LeastSquares(heights, weights)
res = thinkstats2.Residuals(heights, weights, inter, slope)

# %%
var_y = weights.var()
var_res = res.var()
R2 = 1 - var_res / var_y
R2
# Out:
# 0.24853295559408362

# %%
math.sqrt(R2)
# Out:
# 0.49853079703673636

# %%
thinkstats2.Corr(heights, weights)
# Out:
# 0.49852889298398056

# %%
RMSE_without = weights.std()
RMSE_without
# Out:
# 19.565297884235061

# %%
RMSE_with = res.std()
RMSE_with
# Out:
# 16.960608682049976

# %%
(1 - RMSE_with / RMSE_without) * 100
# Out:
# 13.312801152308751
